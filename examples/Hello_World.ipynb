# %% [markdown]
# <a href="https://colab.research.google.com/github/byuruth/Econ484/blob/main/examples/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
print("Hi there!")
# Out:
# Hello, World!
# Hi there!

# %% [markdown]
# Write whatever you want

# %%
# This is a comment Write whatever you want
# I
# Want
# this
# to
# be commented

# %%
# to load data from github:
# !git clone https://github.com/byuruth/Econ484.git
# Out:
# Cloning into 'Econ484'...
# ...

# %%
# Read in housing data
# Import pandas package
import pandas as pd
housingdata=pd.read_csv('econ484/data/housingprices.csv')
housingdata
# Out:
#      price  crime   nox  rooms  dist  radial  proptax  stratio  lowstat  \
# 0    24000  0.006  5.38   6.57  4.09       1     29.6     15.3     4.98
# 1    21599  0.027  4.69   6.42  4.97       2     24.2     17.8     9.14
# 2    34700  0.027  4.69   7.18  4.97       2     24.2     17.8     4.03
# 3    33400  0.032  4.58   7.00  6.06       3     22.2     18.7     2.94
# 4    36199  0.069  4.58   7.15  6.06       3     22.2     18.7     5.33
# ..     ...    ...   ...    ...   ...     ...      ...      ...      ...
# 501  22400  0.063  5.73   6.59  2.48       1     27.3     21.0     9.67
# 502  20600  0.045  5.73   6.12  2.29       1     27.3     21.0     9.08
# 503  23899  0.061  5.73   6.98  2.17       1     27.3     21.0     5.64
# 504  22000  0.110  5.73   6.79  2.39       1     27.3     21.0     6.48
# 505  11900  0.047  5.73   6.03  2.51       1     27.3     21.0     7.88
#
#         lprice      lnox  lproptax
# 0    10.085810  1.682688  5.690360
# ...

# %%
# define outcome variable
y = housingdata['lprice']

# %%
# define X variables (features!)
x=housingdata[['crime','nox','rooms','dist','radial','proptax']]

# %%
# import linear model package from sci-kit learn
from sklearn import linear_model

# %%
# create regression object and fit regression
lm=linear_model.LinearRegression()
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-0.01421792, -0.08451239,  0.27126294, -0.026633  ,  0.00828814,
#        -0.00786517])

# %%
# inspect regression coefficients
print(f"{lm.coef_[2]:.3f}")
# Out:
# 0.271

# %%
# print out a nice sentence that says "the coefficient on ______ is ______" for all x-variables in the model
